# %%
import pandas as pd

# %%
df = pd.read_csv('title.ratings.tsv', sep='\t')
display(df)
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2201
# 1        tt0000002            5.5       312
# 2        tt0000003            6.4      2314
# 3        tt0000004            5.1       197
# 4        tt0000005            6.2      3039
# ...            ...            ...       ...
# 1658150  tt9916846            5.3         7
# 1658151  tt9916848            5.2         7
# 1658152  tt9916850            6.0         7
# 1658153  tt9916852            5.7         7
# 1658154  tt9916880            7.6        11
#
# [1658155 rows x 3 columns]
