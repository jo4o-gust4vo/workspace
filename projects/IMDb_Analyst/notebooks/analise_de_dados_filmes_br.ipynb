# %%
import pandas as pd

# %%
df_filmes_brasileiros = pd.read_csv(r'..\datasets\filmes_brasileiros.csv')
df_filmes_brasileiros.head()
# Out:
# C:\Users\dev-gus\AppData\Local\Temp\ipykernel_8928\2920217564.py:1: DtypeWarning: Columns (0: startYear) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_filmes_brasileiros = pd.read_csv(r'..\datasets\filmes_brasileiros.csv')
#    index    titleId  ordering                        title region language  \
# 0     58  tt0000838         3  Cultura do Cacau em S. Tome     BR       \N
# 1     98  tt0002130        10                      Inferno     BR       \N
# 2    100  tt0002199         2         Da Manjedoura à Cruz     BR       \N
# 3    103  tt0002423         2               Madame DuBarry     BR       \N
# 4    115  tt0003131         6       Maldita seja a guerra!     BR       \N
#
#          types attributes  isOriginalTitle   tconst_x  ...  \
# 0  alternative         \N                0  tt0000838  ...
# 1  imdbDisplay         \N                0  tt0002130  ...
# 2  imdbDisplay         \N                0  tt0002199  ...
# ...
